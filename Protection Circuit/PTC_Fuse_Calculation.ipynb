# %% [markdown]
# # How to select resetable PTC fuses

# %% [markdown]
# Here are the four steps document from Eaton, I will write it in python for easy calculation

# %% [markdown]
# ![image.png](attachment:image.png)
